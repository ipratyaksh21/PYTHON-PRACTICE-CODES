# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x_axis = np.array([11,12,15,18,20])
y_axis =  np.array([5,10,13,17,20])

# %%
plt.plot(x_axis,y_axis)

# %%
plt.plot(x_axis,y_axis,marker = 'o')

# %%
plt.plot(x_axis,y_axis,marker = '*')

# %%
plt.plot(x_axis,y_axis,marker = 'D',color ='r')
# plt.xlabel("X-Axis")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14128\154903681.py in <module>
#       1 plt.plot(x_axis,y_axis,marker = 'D',color ='r')
#       2 # plt.xlabel("X-Axis")
# ----> 3 plt.xlabel("Average Pulse")
#       4 plt.ylabel("Calorie Burnage")
#       5 plt.show()
#
# TypeError: 'str' object is not callable

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("Data Ananlysis")
# plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()
